# %% [markdown]
# ### 1. Importing Datatset and Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
comcast_consumer=pd.read_csv("Comcast Telecom Complaints data.csv")
comcast_consumer
# Out:
#      Ticket #                                 Customer Complaint        Date  \
# 0      250635                      Comcast Cable Internet Speeds  22-04-2015
# 1      223441       Payment disappear - service got disconnected    4/8/2015
# 2      242732                                  Speed and Service  18-04-2015
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ...    5/7/2015
# 4      307175         Comcast not working and no service to boot  26-05-2015
# ...       ...                                                ...         ...
# 2219   213550                               Service Availability    4/2/2015
# 2220   318775         Comcast Monthly Billing for Returned Modem    6/2/2015
# 2221   331188                            complaint about comcast    6/9/2015
# 2222   360489             Extremely unsatisfied Comcast customer  23-06-2015
# 2223   363614               Comcast, Ypsilanti MI Internet Speed  24-06-2015
#
# ...

# %% [markdown]
# ### 2. Reading column names in the dataset

# %%
print(comcast_consumer.columns)
# Out:
# Index(['Ticket #', 'Customer Complaint', 'Date', 'Time', 'Received Via',
#        'City', 'State', 'Zip code', 'Status', 'Filing on Behalf of Someone'],
#       dtype='object')

# %% [markdown]
# ### 3. Converting and formating the values in the 'Date' column

# %%
pd.to_datetime(comcast_consumer.Date)
# Out:
# 0      2015-04-22
# 1      2015-04-08
# 2      2015-04-18
# 3      2015-05-07
# 4      2015-05-26
#           ...
# 2219   2015-04-02
# 2220   2015-06-02
# 2221   2015-06-09
# 2222   2015-06-23
# 2223   2015-06-24
# Name: Date, Length: 2224, dtype: datetime64[ns]

# %%
comcast_consumer.dtypes
# Out:
# Ticket #                       object
# Customer Complaint             object
# Date                           object
# Time                           object
# Received Via                   object
# City                           object
# State                          object
# Zip code                        int64
# Status                         object
# Filing on Behalf of Someone    object
# dtype: object

# %%
comcast_consumer['Date']=pd.to_datetime(comcast_consumer.Date)
comcast_consumer
# Out:
#      Ticket #                                 Customer Complaint       Date  \
# 0      250635                      Comcast Cable Internet Speeds 2015-04-22
# 1      223441       Payment disappear - service got disconnected 2015-04-08
# 2      242732                                  Speed and Service 2015-04-18
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ... 2015-05-07
# 4      307175         Comcast not working and no service to boot 2015-05-26
# ...       ...                                                ...        ...
# 2219   213550                               Service Availability 2015-04-02
# 2220   318775         Comcast Monthly Billing for Returned Modem 2015-06-02
# 2221   331188                            complaint about comcast 2015-06-09
# 2222   360489             Extremely unsatisfied Comcast customer 2015-06-23
# 2223   363614               Comcast, Ypsilanti MI Internet Speed 2015-06-24
#
# ...

# %%
comcast_consumer.dtypes
# Out:
# Ticket #                               object
# Customer Complaint                     object
# Date                           datetime64[ns]
# Time                                   object
# Received Via                           object
# City                                   object
# State                                  object
# Zip code                                int64
# Status                                 object
# Filing on Behalf of Someone            object
# dtype: object

# %%
import datetime as dt

# %%
comcast_consumer['Date']=comcast_consumer.Date.dt.strftime('%d-%B-%y')

# %%
comcast_consumer
# Out:
#      Ticket #                                 Customer Complaint         Date  \
# 0      250635                      Comcast Cable Internet Speeds  22-April-15
# 1      223441       Payment disappear - service got disconnected  08-April-15
# 2      242732                                  Speed and Service  18-April-15
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ...    07-May-15
# 4      307175         Comcast not working and no service to boot    26-May-15
# ...       ...                                                ...          ...
# 2219   213550                               Service Availability  02-April-15
# 2220   318775         Comcast Monthly Billing for Returned Modem   02-June-15
# 2221   331188                            complaint about comcast   09-June-15
# 2222   360489             Extremely unsatisfied Comcast customer   23-June-15
# 2223   363614               Comcast, Ypsilanti MI Internet Speed   24-June-15
#
# ...

# %% [markdown]
# ### 4. Daily complaints frequency chart

# %%
Daily_freq = comcast_consumer['Date'].value_counts()

# %%
Daily_freq
# Out:
# 24-June-15     218
# 23-June-15     190
# 25-June-15      98
# 26-June-15      55
# 30-June-15      53
#               ...
# 02-May-15        7
# 17-May-15        7
# 05-April-15      6
# 03-May-15        5
# 11-April-15      5
# Name: Date, Length: 91, dtype: int64

# %%
Date=Daily_freq.keys()
Date
# Out:
# Index(['24-June-15', '23-June-15', '25-June-15', '26-June-15', '30-June-15',
#        '29-June-15', '18-June-15', '12-June-15', '27-June-15', '15-June-15',
#        '13-June-15', '17-June-15', '22-June-15', '19-June-15', '05-June-15',
#        '16-June-15', '08-April-15', '02-April-15', '26-May-15', '28-June-15',
#        '28-May-15', '28-April-15', '27-April-15', '01-June-15', '10-June-15',
#        '02-June-15', '07-April-15', '03-June-15', '13-April-15', '30-April-15',
#        '08-June-15', '24-April-15', '14-April-15', '23-April-15', '09-June-15',
#        '22-April-15', '29-April-15', '17-April-15', '11-June-15',
#        '09-April-15', '10-April-15', '16-April-15', '20-April-15',
#        '01-April-15', '27-May-15', '21-May-15', '16-May-15', '14-June-15',
#        '25-April-15', '20-June-15', '08-May-15', '12-April-15', '03-April-15',
#        '14-May-15', '07-May-15', '20-May-15', '06-May-15', '05-May-15',
# ...

# %%
Frequency=Daily_freq.values
Frequency
# Out:
# array([218, 190,  98,  55,  53,  51,  47,  43,  39,  34,  32,  32,  30,
#         29,  29,  29,  28,  27,  27,  27,  26,  26,  25,  25,  25,  25,
#         25,  25,  24,  24,  24,  24,  23,  23,  23,  22,  22,  21,  21,
#         21,  21,  20,  20,  18,  17,  17,  16,  16,  16,  16,  15,  15,
#         15,  15,  15,  15,  14,  14,  14,  14,  14,  13,  12,  12,  12,
#         12,  12,  12,  12,  12,  12,  12,  12,  12,  12,  11,  11,  10,
#          9,   9,   9,   8,   8,   7,   7,   7,   7,   7,   6,   5,   5],
#       dtype=int64)

# %%
Daily_freq=pd.DataFrame({'Date': Date,'Frequency': Frequency})
Daily_freq
# Out:
#            Date  Frequency
# 0    24-June-15        218
# 1    23-June-15        190
# 2    25-June-15         98
# 3    26-June-15         55
# 4    30-June-15         53
# ..          ...        ...
# 86    02-May-15          7
# 87    17-May-15          7
# 88  05-April-15          6
# 89    03-May-15          5
# 90  11-April-15          5
#
# [91 rows x 2 columns]

# %%
plt.bar(Daily_freq['Date'], Daily_freq['Frequency'])
plt.xlabel('Date')
plt.ylabel('Number of complaints')
plt.title('Daily Complaints Frequency Chart')
plt.show()

# %% [markdown]
# Highest number of complaints received is 218 on 24th June 2015.

# %% [markdown]
# ### 5. Monthly complaints frequency chart

# %%
comcast_consumer['Date']=pd.to_datetime(comcast_consumer.Date)
comcast_consumer['Date']=comcast_consumer.Date.dt.strftime('%B')
comcast_consumer
# Out:
#      Ticket #                                 Customer Complaint   Date  \
# 0      250635                      Comcast Cable Internet Speeds  April
# 1      223441       Payment disappear - service got disconnected  April
# 2      242732                                  Speed and Service  April
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ...    May
# 4      307175         Comcast not working and no service to boot    May
# ...       ...                                                ...    ...
# 2219   213550                               Service Availability  April
# 2220   318775         Comcast Monthly Billing for Returned Modem   June
# 2221   331188                            complaint about comcast   June
# 2222   360489             Extremely unsatisfied Comcast customer   June
# 2223   363614               Comcast, Ypsilanti MI Internet Speed   June
#
#              Time        Received Via        City     State  Zip code  Status  \
# ...

# %%
Monthly_freq = comcast_consumer['Date'].value_counts()
Monthly_freq
# Out:
# June     1280
# April     545
# May       399
# Name: Date, dtype: int64

# %%
Month =Monthly_freq.keys()
Month
# Out:
# Index(['June', 'April', 'May'], dtype='object')

# %%
Frequency= Monthly_freq.values
Frequency
# Out:
# array([1280,  545,  399], dtype=int64)

# %%
Monthly_freq=pd.DataFrame({'Month': Month,'Frequency': Frequency})
Monthly_freq
# Out:
#    Month  Frequency
# 0   June       1280
# 1  April        545
# 2    May        399

# %%
plt.bar(Monthly_freq['Month'], Monthly_freq['Frequency'])
plt.xlabel('Month')
plt.ylabel('Number of complaints')
plt.title('Monthly Complaints Frequency Chart')
plt.show()

# %% [markdown]
# As we have seen in the daily frequency data chart, the number of complaints received in a day is higher for the month of June (first five instances in the daily frequency chart shows the same).
# Hence, the number of complaints received is higher for the month of June.

# %% [markdown]
# ### 6. Type of complaint registered more number of times

# %%
import nltk
import os
import nltk.corpus
import re
import string

# %%
Freq_complaints = comcast_consumer['Customer Complaint']
Freq_complaints
# Out:
# 0                           Comcast Cable Internet Speeds
# 1            Payment disappear - service got disconnected
# 2                                       Speed and Service
# 3       Comcast Imposed a New Usage Cap of 300GB that ...
# 4              Comcast not working and no service to boot
#                               ...
# 2219                                 Service Availability
# 2220           Comcast Monthly Billing for Returned Modem
# 2221                              complaint about comcast
# 2222               Extremely unsatisfied Comcast customer
# 2223                 Comcast, Ypsilanti MI Internet Speed
# Name: Customer Complaint, Length: 2224, dtype: object

# %%
Freq_complaints = str(Freq_complaints)
Freq_complaints
# Out:
# '0                           Comcast Cable Internet Speeds\n1            Payment disappear - service got disconnected\n2                                       Speed and Service\n3       Comcast Imposed a New Usage Cap of 300GB that ...\n4              Comcast not working and no service to boot\n                              ...                        \n2219                                 Service Availability\n2220           Comcast Monthly Billing for Returned Modem\n2221                              complaint about comcast\n2222               Extremely unsatisfied Comcast customer\n2223                 Comcast, Ypsilanti MI Internet Speed\nName: Customer Complaint, Length: 2224, dtype: object'

# %%
nltk.download('punkt')
corpus = nltk.word_tokenize(Freq_complaints)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
corpus
# Out:
# ['0',
#  'Comcast',
#  'Cable',
#  'Internet',
#  'Speeds',
#  '1',
#  'Payment',
#  'disappear',
#  '-',
#  'service',
#  'got',
#  'disconnected',
#  '2',
#  'Speed',
#  'and',
#  'Service',
#  '3',
#  'Comcast',
#  'Imposed',
#  'a',
#  'New',
#  'Usage',
#  'Cap',
#  'of',
#  '300GB',
#  'that',
#  '...',
#  '4',
#  'Comcast',
#  'not',
#  'working',
#  'and',
#  'no',
#  'service',
#  'to',
#  'boot',
#  '...',
#  '2219',
#  'Service',
#  'Availability',
#  '2220',
#  'Comcast',
#  'Monthly',
#  'Billing',
#  'for',
#  'Returned',
#  'Modem',
#  '2221',
#  'complaint',
#  'about',
#  'comcast',
#  '2222',
#  'Extremely',
#  'unsatisfied',
#  'Comcast',
#  'customer',
#  '2223',
#  'Comcast',
#  ',',
#  'Ypsilanti',
#  'MI',
#  'Internet',
#  'Speed',
#  'Name',
#  ':',
#  'Customer',
#  'Complaint',
#  ',',
#  'Length',
#  ':',
#  '2224',
#  ',',
#  'dtype',
#  ':',
#  'object']

# %%
for i in range(len(corpus )):
    corpus [i] = corpus [i].lower() 
    corpus [i] = re.sub(r'\W',' ',corpus [i]) 
    corpus [i] = re.sub(r'\s+','',corpus [i])

# %%
print(len(corpus))
# Out:
# 75

# %%
wordfreq = {}
for word in corpus: 
    tokens = nltk.word_tokenize(word) 
    for token in tokens:
        if token not in wordfreq.keys():
            wordfreq[token] = 1 
        else:
            wordfreq[token] += 1

# %%
print(wordfreq)
# Out:
# {'0': 1, 'comcast': 7, 'cable': 1, 'internet': 2, 'speeds': 1, '1': 1, 'payment': 1, 'disappear': 1, 'service': 4, 'got': 1, 'disconnected': 1, '2': 1, 'speed': 2, 'and': 2, '3': 1, 'imposed': 1, 'a': 1, 'new': 1, 'usage': 1, 'cap': 1, 'of': 1, '300gb': 1, 'that': 1, '4': 1, 'not': 1, 'working': 1, 'no': 1, 'to': 1, 'boot': 1, '2219': 1, 'availability': 1, '2220': 1, 'monthly': 1, 'billing': 1, 'for': 1, 'returned': 1, 'modem': 1, '2221': 1, 'complaint': 2, 'about': 1, '2222': 1, 'extremely': 1, 'unsatisfied': 1, 'customer': 2, '2223': 1, 'ypsilanti': 1, 'mi': 1, 'name': 1, 'length': 1, '2224': 1, 'dtype': 1, 'object': 1}

# %%
import heapq
most_freq = heapq.nlargest(20, wordfreq, key=wordfreq.get)

# %%
most_freq
# Out:
# ['comcast',
#  'service',
#  'internet',
#  'speed',
#  'and',
#  'complaint',
#  'customer',
#  '0',
#  'cable',
#  'speeds',
#  '1',
#  'payment',
#  'disappear',
#  'got',
#  'disconnected',
#  '2',
#  '3',
#  'imposed',
#  'a',
#  'new']

# %% [markdown]
# Since the word 'Comcast' is the name of the company and other words such as service, internet and speed are related to the complaint types, from the 'Most_freq' dataset we can derive that more number of complaints registered are regarding the service, internet and speed issue.

# %% [markdown]
# ### 7. Replacing 'Pending' and 'Solved' values as 'Open' and 'Closed' respectively

# %%
comcast_consumer['Status']=comcast_consumer['Status'].replace(['Pending','Solved'],['Open','Closed'])
comcast_consumer
# Out:
#      Ticket #                                 Customer Complaint   Date  \
# 0      250635                      Comcast Cable Internet Speeds  April
# 1      223441       Payment disappear - service got disconnected  April
# 2      242732                                  Speed and Service  April
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ...    May
# 4      307175         Comcast not working and no service to boot    May
# ...       ...                                                ...    ...
# 2219   213550                               Service Availability  April
# 2220   318775         Comcast Monthly Billing for Returned Modem   June
# 2221   331188                            complaint about comcast   June
# 2222   360489             Extremely unsatisfied Comcast customer   June
# 2223   363614               Comcast, Ypsilanti MI Internet Speed   June
#
#              Time        Received Via        City     State  Zip code  Status  \
# ...

# %% [markdown]
# Here, to bring about the uniformity in the dataset the 'Pending' and 'Solved' values in the Status column are replaced
# by 'Open' and 'Closed', respectively.

# %% [markdown]
# ### 8. Statewise complaint status stacked bar chart

# %%
Open_Status = comcast_consumer.loc[(comcast_consumer.Status == "Open")]
Open_Status
# Out:
#      Ticket #                                 Customer Complaint  Date  \
# 3      277946  Comcast Imposed a New Usage Cap of 300GB that ...   May
# 6      361148      Throttling service and unreasonable data caps  June
# 9      371214  Comcast Raising Prices and Not Being Available...  June
# 12     339282  Comcast Violating Open Internet Rules by Block...  June
# 15     370137                                 Internet complaint  June
# ...       ...                                                ...   ...
# 2196   339481             Terrible internet service from Comcast  June
# 2202   305166                                    comcst data cap   May
# 2208   374570                                        comcast cap  June
# 2218   338192    Speed throttling, speeds not at promised output  June
# 2223   363614               Comcast, Ypsilanti MI Internet Speed  June
#
#              Time        Received Via         City       State  Zip code  \
# ...

# %%
K = Open_Status['State'].value_counts()
K
# Out:
# Georgia                 80
# California              61
# Tennessee               47
# Florida                 39
# Illinois                29
# Michigan                23
# Washington              23
# Texas                   22
# Colorado                22
# Pennsylvania            20
# New Jersey              19
# Mississippi             16
# Maryland                15
# Oregon                  13
# Virginia                11
# Massachusetts           11
# Alabama                  9
# Indiana                  9
# Utah                     6
# Arizona                  6
# Minnesota                4
# New Hampshire            4
# Delaware                 4
# New Mexico               4
# Connecticut              3
# Kentucky                 3
# West Virginia            3
# South Carolina           3
# District Of Columbia     2
# Maine                    2
# Louisiana                1
# Vermont                  1
# Kansas                   1
# Missouri                 1
# ...

# %%
State = K.keys()
State
# Out:
# Index(['Georgia', 'California', 'Tennessee', 'Florida', 'Illinois', 'Michigan',
#        'Washington', 'Texas', 'Colorado', 'Pennsylvania', 'New Jersey',
#        'Mississippi', 'Maryland', 'Oregon', 'Virginia', 'Massachusetts',
#        'Alabama', 'Indiana', 'Utah', 'Arizona', 'Minnesota', 'New Hampshire',
#        'Delaware', 'New Mexico', 'Connecticut', 'Kentucky', 'West Virginia',
#        'South Carolina', 'District Of Columbia', 'Maine', 'Louisiana',
#        'Vermont', 'Kansas', 'Missouri'],
#       dtype='object')

# %%
Open_counts = K.values
Open_counts
# Out:
# array([80, 61, 47, 39, 29, 23, 23, 22, 22, 20, 19, 16, 15, 13, 11, 11,  9,
#         9,  6,  6,  4,  4,  4,  4,  3,  3,  3,  3,  2,  2,  1,  1,  1,  1],
#       dtype=int64)

# %%
Open = pd.DataFrame({'State': State,'Open_counts':Open_counts})
Open
# Out:
#                    State  Open_counts
# 0                Georgia           80
# 1             California           61
# 2              Tennessee           47
# 3                Florida           39
# 4               Illinois           29
# 5               Michigan           23
# 6             Washington           23
# 7                  Texas           22
# 8               Colorado           22
# 9           Pennsylvania           20
# 10            New Jersey           19
# 11           Mississippi           16
# 12              Maryland           15
# 13                Oregon           13
# 14              Virginia           11
# 15         Massachusetts           11
# 16               Alabama            9
# 17               Indiana            9
# 18                  Utah            6
# 19               Arizona            6
# 20             Minnesota            4
# 21         New Hampshire            4
# 22              Delaware            4
# 23            New Mexico            4
# ...

# %% [markdown]
# In the above chart it is seen that the State of 'Georgia' has the higher number of 'Open' complaints that is 80.

# %%
Open.columns
# Out:
# Index(['State', 'Open_counts'], dtype='object')

# %%
Closed_Status = comcast_consumer.loc[(comcast_consumer.Status == "Closed")]
Closed_Status
# Out:
#      Ticket #                                 Customer Complaint   Date  \
# 0      250635                      Comcast Cable Internet Speeds  April
# 1      223441       Payment disappear - service got disconnected  April
# 2      242732                                  Speed and Service  April
# 4      307175         Comcast not working and no service to boot    May
# 5      338519  ISP Charging for arbitrary data limits with ov...   June
# ...       ...                                                ...    ...
# 2217   254488                     problems with internet service  April
# 2219   213550                               Service Availability  April
# 2220   318775         Comcast Monthly Billing for Returned Modem   June
# 2221   331188                            complaint about comcast   June
# 2222   360489             Extremely unsatisfied Comcast customer   June
#
#              Time        Received Via        City         State  Zip code  \
# ...

# %%
P = Closed_Status['State'].value_counts()
P
# Out:
# Georgia                 208
# Florida                 201
# California              159
# Illinois                135
# Pennsylvania            110
# Tennessee                96
# Michigan                 92
# Washington               75
# Maryland                 63
# Colorado                 58
# New Jersey               56
# Indiana                  50
# Massachusetts            50
# Virginia                 49
# Texas                    49
# Oregon                   36
# Minnesota                29
# Mississippi              23
# Alabama                  17
# Utah                     16
# South Carolina           15
# District Of Columbia     14
# Arizona                  14
# Louisiana                12
# New Mexico               11
# Connecticut               9
# West Virginia             8
# New Hampshire             8
# Delaware                  8
# Arkansas                  6
# New York                  6
# Kentucky                  4
# Missouri                  3
# ...

# %%
State = P.keys()
State
# Out:
# Index(['Georgia', 'Florida', 'California', 'Illinois', 'Pennsylvania',
#        'Tennessee', 'Michigan', 'Washington', 'Maryland', 'Colorado',
#        'New Jersey', 'Indiana', 'Massachusetts', 'Virginia', 'Texas', 'Oregon',
#        'Minnesota', 'Mississippi', 'Alabama', 'Utah', 'South Carolina',
#        'District Of Columbia', 'Arizona', 'Louisiana', 'New Mexico',
#        'Connecticut', 'West Virginia', 'New Hampshire', 'Delaware', 'Arkansas',
#        'New York', 'Kentucky', 'Missouri', 'Ohio', 'Maine', 'North Carolina',
#        'Vermont', 'District of Columbia', 'Montana', 'Iowa', 'Rhode Island',
#        'Kansas', 'Nevada'],
#       dtype='object')

# %%
Closed_counts = P.values
Closed_counts
# Out:
# array([208, 201, 159, 135, 110,  96,  92,  75,  63,  58,  56,  50,  50,
#         49,  49,  36,  29,  23,  17,  16,  15,  14,  14,  12,  11,   9,
#          8,   8,   8,   6,   6,   4,   3,   3,   3,   3,   2,   1,   1,
#          1,   1,   1,   1], dtype=int64)

# %%
Closed = pd.DataFrame({'State': State,'Closed_counts':Closed_counts})
Closed
# Out:
#                    State  Closed_counts
# 0                Georgia            208
# 1                Florida            201
# 2             California            159
# 3               Illinois            135
# 4           Pennsylvania            110
# 5              Tennessee             96
# 6               Michigan             92
# 7             Washington             75
# 8               Maryland             63
# 9               Colorado             58
# 10            New Jersey             56
# 11               Indiana             50
# 12         Massachusetts             50
# 13              Virginia             49
# 14                 Texas             49
# 15                Oregon             36
# 16             Minnesota             29
# 17           Mississippi             23
# 18               Alabama             17
# 19                  Utah             16
# 20        South Carolina             15
# 21  District Of Columbia             14
# ...

# %% [markdown]
# In the above chart it is seen that the state of 'Georgia' has highest number of closed complaints that is 208.

# %%
Statewise_status = Closed.merge(Open,how='left')

# %%
Statewise_status
# Out:
#                    State  Closed_counts  Open_counts
# 0                Georgia            208         80.0
# 1                Florida            201         39.0
# 2             California            159         61.0
# 3               Illinois            135         29.0
# 4           Pennsylvania            110         20.0
# 5              Tennessee             96         47.0
# 6               Michigan             92         23.0
# 7             Washington             75         23.0
# 8               Maryland             63         15.0
# 9               Colorado             58         22.0
# 10            New Jersey             56         19.0
# 11               Indiana             50          9.0
# 12         Massachusetts             50         11.0
# 13              Virginia             49         11.0
# 14                 Texas             49         22.0
# 15                Oregon             36         13.0
# 16             Minnesota             29          4.0
# ...

# %% [markdown]
# Two datasets, 'Open_counts' and 'Closed_counts' are merged to form a new dataset named 'Statewise_status'.

# %%
Statewise_status.dtypes
# Out:
# State             object
# Closed_counts      int64
# Open_counts      float64
# dtype: object

# %%
Statewise_status["Open_counts"] = Statewise_status["Open_counts"].fillna(0)
print(Statewise_status)
# Out:
#                    State  Closed_counts  Open_counts
# 0                Georgia            208         80.0
# 1                Florida            201         39.0
# 2             California            159         61.0
# 3               Illinois            135         29.0
# 4           Pennsylvania            110         20.0
# 5              Tennessee             96         47.0
# 6               Michigan             92         23.0
# 7             Washington             75         23.0
# 8               Maryland             63         15.0
# 9               Colorado             58         22.0
# 10            New Jersey             56         19.0
# 11               Indiana             50          9.0
# 12         Massachusetts             50         11.0
# 13              Virginia             49         11.0
# 14                 Texas             49         22.0
# 15                Oregon             36         13.0
# 16             Minnesota             29          4.0
# ...

# %% [markdown]
# Above, the NaN values are replaced with 0.

# %%
Statewise_status.plot(kind='bar', stacked = True)
plt.xlabel('State')
plt.ylabel('Number of Open and Closed complaints')
plt.title('Statewise Complaints Status Chart')
plt.show()

# %% [markdown]
# Above stacked bar chart shows the number of closed and open complaints for all the states.
# The state of 'Georgia' has the highest number of open and closed complaints as the total complaints are also high for this state.

# %% [markdown]
# ### 9. State with maximum number of complaints

# %%
Maximum_complaints = comcast_consumer['State'].value_counts()
max(Maximum_complaints)
# Out:
# 288

# %%
Maximum_complaints
# Out:
# Georgia                 288
# Florida                 240
# California              220
# Illinois                164
# Tennessee               143
# Pennsylvania            130
# Michigan                115
# Washington               98
# Colorado                 80
# Maryland                 78
# New Jersey               75
# Texas                    71
# Massachusetts            61
# Virginia                 60
# Indiana                  59
# Oregon                   49
# Mississippi              39
# Minnesota                33
# Alabama                  26
# Utah                     22
# Arizona                  20
# South Carolina           18
# District Of Columbia     16
# New Mexico               15
# Louisiana                13
# New Hampshire            12
# Delaware                 12
# Connecticut              12
# West Virginia            11
# Kentucky                  7
# New York                  6
# Arkansas                  6
# Maine                     5
# ...

# %% [markdown]
# With 288 complaints the state of 'Georgia' has highest number of complaints, followed by the 'Florida' and 'California'
# with 240 and 220 complaints, respectively.

# %% [markdown]
# ### 10.  State with highest percentage of unresolved complaints

# %%
Open['Percentage_of_Unresolved_complaints']= Open['Open_counts']/sum(Open_counts)*100

# %%
Open
# Out:
#                    State  Open_counts  Percentage_of_Unresolved_complaints
# 0                Georgia           80                            15.473888
# 1             California           61                            11.798839
# 2              Tennessee           47                             9.090909
# 3                Florida           39                             7.543520
# 4               Illinois           29                             5.609284
# 5             Washington           23                             4.448743
# 6               Michigan           23                             4.448743
# 7                  Texas           22                             4.255319
# 8               Colorado           22                             4.255319
# 9           Pennsylvania           20                             3.868472
# 10            New Jersey           19                             3.675048
# ...

# %%
Open['Percentage_of_Unresolved_complaints'].max()
# Out:
# 15.473887814313347

# %% [markdown]
# The above calculation shows the percentage of open complaints for the states with respect to the total number of open complaints.
# The percentage of the open complaints is high for the state of 'Georgia' with 15.47%.

# %% [markdown]
# ### 11. Percentage of the total resolved complaints received via 'Internet' and 'Customer Care Call'

# %%
comcast_consumer.columns
# Out:
# Index(['Ticket #', 'Customer Complaint', 'Date', 'Time', 'Received Via',
#        'City', 'State', 'Zip code', 'Status', 'Filing on Behalf of Someone'],
#       dtype='object')

# %%
comcast_consumer['Received Via'].value_counts()
# Out:
# Customer Care Call    1119
# Internet              1105
# Name: Received Via, dtype: int64

# %% [markdown]
# As required,the entire datset comprise of the complaints received via internet and customer care call, hence taking the data as it is.

# %%
Total_complaints  = comcast_consumer['Status'].value_counts()
Total_complaints
# Out:
# Closed    1707
# Open       517
# Name: Status, dtype: int64

# %%
Total_complaints = sum(Total_complaints )
Total_complaints
# Out:
# 2224

# %% [markdown]
# The total number of complaints received by all the states is 2224.

# %%
Total_Resolved_complaints = sum(Closed['Closed_counts'])
Total_Resolved_complaints
# Out:
# 1707

# %% [markdown]
# The total number of complaints resolved by all the states is 1707.

# %%
Percentage_of_resolved_complaints =Total_Resolved_complaints/Total_complaints*100
Percentage_of_resolved_complaints
# Out:
# 76.75359712230215

# %% [markdown]
# The percentage of complaints resolved is 76.75%.
